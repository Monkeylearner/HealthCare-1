# %%
import numpy as np
import pandas as pd
import plotly.plotly as py
import plotly.tools as tls
import plotly.figure_factory as ff
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
tls.set_credentials_file(username='bjemison',api_key='PZfb19V86MDeRauUq27F')

# %%
states = pd.read_excel('us_healthcare.xls')

# %%
states.head()
# Out:
#   Code    Location  2014_Health_Spending  2013_Health_Spending  \
# 0   AL     Alabama                  7281                  6996
# 1   AK      Alaska                 11064                 10428
# 2   AZ     Arizona                  6452                  6262
# 3   AR    Arkansas                  7408                  6929
# 4   CA  California                  7549                  7256
#
#    2012_Health_Spending  2011_Health_Spending  2010_Health_Spending  \
# 0                  6821                  6541                  6421
# 1                 10130                  9586                  9129
# 2                  6183                  6076                  6027
# 3                  6804                  6585                  6412
# 4                  7018                  6737                  6480
#
#    2014_Smoking  2013_Smoking  2012_Smoking     ...       2012_Middle_Adult   \
# 0      0.277492      0.275937      0.279381     ...                33.359722
# ...

# %%
states['2014_Health_Spending'] = states['2014_Health_Spending'].astype(float)
states['2013_Health_Spending'] = states['2013_Health_Spending'].astype(float)
states['2012_Health_Spending'] = states['2012_Health_Spending'].astype(float)
states['2011_Health_Spending'] = states['2012_Health_Spending'].astype(float)
states['2010_Health_Spending'] = states['2010_Health_Spending'].astype(float)
states['2014_Income'] = states['2014_Income'].astype(float)
states['2013_Income'] = states['2013_Income'].astype(float)
states['2012_Income'] = states['2012_Income'].astype(float)
states['2011_Income'] = states['2011_Income'].astype(float)
states['2010_Income'] = states['2010_Income'].astype(float)

# %%
for col in states.columns:
    states[col] = states[col].astype(str)

# %%
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
        [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

# %%
states['text'] = states['Location'] + '<br>' +\
    'Healthcare Cost '+states['2014_Health_Spending']

# %%
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = states['Code'],
        z = states['2014_Health_Spending'].astype(float),
        locationmode = 'USA-states',
        text = states['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "USD $"
        )
    ) ]

layout = dict(
        title = 'Health Care Spending per Capita by State',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

# %%
fig = dict(data=data, layout=layout)

# %%
url = py.plot(fig, filename='d3-cloropleth-map')

# %%
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bjemison/2.embed" height="525px" width="100%"></iframe>

# %%
states['2014_Health_Spending'] = states['2014_Health_Spending'].astype(float)
states['2013_Health_Spending'] = states['2013_Health_Spending'].astype(float)
states['2012_Health_Spending'] = states['2012_Health_Spending'].astype(float)
states['2011_Health_Spending'] = states['2012_Health_Spending'].astype(float)
states['2010_Health_Spending'] = states['2010_Health_Spending'].astype(float)
states['2014_Income'] = states['2014_Income'].astype(float)
states['2013_Income'] = states['2013_Income'].astype(float)
states['2012_Income'] = states['2012_Income'].astype(float)
states['2011_Income'] = states['2011_Income'].astype(float)
states['2010_Income'] = states['2010_Income'].astype(float)
states['2014_Male'] = states['2014_Male'].astype(float)
states['2014_Female'] = states['2014_Female'].astype(float)

# %%
states.head()
# Out:
#   Code    Location  2014_Health_Spending  2013_Health_Spending  \
# 0   AL     Alabama                7281.0                6996.0
# 1   AK      Alaska               11064.0               10428.0
# 2   AZ     Arizona                6452.0                6262.0
# 3   AR    Arkansas                7408.0                6929.0
# 4   CA  California                7549.0                7256.0
#
#    2012_Health_Spending  2011_Health_Spending  2010_Health_Spending  \
# 0                6821.0                6821.0                6421.0
# 1               10130.0               10130.0                9129.0
# 2                6183.0                6183.0                6027.0
# 3                6804.0                6804.0                6412.0
# 4                7018.0                7018.0                6480.0
#
#           2014_Smoking         2013_Smoking         2012_Smoking  \
# 0   0.2774920634920634  0.27593650793650787   0.2793809523809524
# ...

# %%
data_2014 = plt.scatter(states['2014_Income'],states['2014_Health_Spending'], marker='o', facecolors='red',alpha=0.25)
data_2013 = plt.scatter(states['2013_Income'],states['2013_Health_Spending'],marker='o',facecolors='orange',alpha=0.25)
data_2012 = plt.scatter(states['2012_Income'],states['2012_Health_Spending'],marker='o',facecolors='g',alpha=0.25)
data_2011 = plt.scatter(states['2011_Income'],states['2011_Health_Spending'],marker='o',facecolors='purple',alpha=0.25)
data_2010 = plt.scatter(states['2010_Income'],states['2010_Health_Spending'],marker='o',facecolors='g',alpha=0.25)
plt.title('US Income and GDP Data')

chart_legend = plt.legend(handles=[data_2014,data_2013,data_2012,data_2011,data_2010],fontsize=10)
chart_legend.legendHandles[0]._sizes = [25]
chart_legend.legendHandles[1]._sizes = [25]
chart_legend.legendHandles[2]._sizes = [25]
chart_legend.legendHandles[3]._sizes = [25]
chart_legend.legendHandles[4]._sizes = [25]
plt.xlabel('US Income by State ($)')
plt.ylabel('Health Care Spending ($)')
plt.grid()

# %%
male_data_2014 = plt.scatter(states['2014_Male'],states['2014_Health_Spending'], marker='o', facecolors='red',alpha=0.25)
male_data_2013 = plt.scatter(states['2013_Male'],states['2013_Health_Spending'],marker='o',facecolors='orange',alpha=0.25)
male_data_2012 = plt.scatter(states['2012_Male'],states['2012_Health_Spending'],marker='o',facecolors='g',alpha=0.25)
male_data_2011 = plt.scatter(states['2011_Male'],states['2011_Health_Spending'],marker='o',facecolors='purple',alpha=0.25)
male_data_2010 = plt.scatter(states['2010_Male'],states['2010_Health_Spending'],marker='o',facecolors='g',alpha=0.25)
plt.title('Male Citizens Data')

chart_legend = plt.legend(handles=[male_data_2014,male_data_2013,male_data_2012,male_data_2011,male_data_2010],fontsize=10)
chart_legend.legendHandles[0]._sizes = [25]
chart_legend.legendHandles[1]._sizes = [25]
chart_legend.legendHandles[2]._sizes = [25]
chart_legend.legendHandles[3]._sizes = [25]
chart_legend.legendHandles[4]._sizes = [25]
plt.xlabel('US Income by State ($)')
plt.ylabel('Health Care Spending ($)')
plt.grid()

# %%
states.head()
# Out:
#   Code    Location  2014_Health_Spending  2013_Health_Spending  \
# 0   AL     Alabama                7281.0                6996.0
# 1   AK      Alaska               11064.0               10428.0
# 2   AZ     Arizona                6452.0                6262.0
# 3   AR    Arkansas                7408.0                6929.0
# 4   CA  California                7549.0                7256.0
#
#    2012_Health_Spending  2011_Health_Spending  2010_Health_Spending  \
# 0                6821.0                6821.0                6421.0
# 1               10130.0               10130.0                9129.0
# 2                6183.0                6183.0                6027.0
# 3                6804.0                6804.0                6412.0
# 4                7018.0                7018.0                6480.0
#
#           2014_Smoking         2013_Smoking         2012_Smoking  \
# 0   0.2774920634920634  0.27593650793650787   0.2793809523809524
# ...

# %%
states['2014_Male'] = states['2014_Male'].astype(float)
states['2013_Male'] = states['2013_Male'].astype(float)
states['2012_Male'] = states['2012_Male'].astype(float)
states['2011_Male'] = states['2011_Male'].astype(float)
states['2010_Male'] = states['2010_Male'].astype(float)

# %%
col = states.loc[:,['2014_Male','2013_Male','2012_Male','2011_Male','2010_Male']]
states['Male_Average'] = col.mean(axis=1)
states['Male_Average']
#col = df.loc[: , "salary_1":"salary_3"]
# Out:
# 0     48.508359
# 1     52.181701
# 2     49.709757
# 3     49.108183
# 4     49.671700
# 5     50.136649
# 6     48.723631
# 7     48.423942
# 8     47.380259
# 9     48.890921
# 10    48.806974
# 11    50.155404
# 12    50.085117
# 13    49.066711
# 14    49.233381
# 15    49.596899
# 16    49.697361
# 17    49.223406
# 18    48.939136
# 19    48.965521
# 20    48.423149
# 21    48.431488
# 22    49.092604
# 23    49.670998
# 24    48.584083
# 25    49.022133
# 26    50.223156
# 27    49.709410
# 28    50.375681
# 29    49.375829
# 30    48.733654
# 31    49.458255
# 32    48.454843
# 33    48.727793
# 34    50.881160
# 35    48.883690
# 36    49.509322
# 37    49.489449
# 38    48.830088
# 39    48.401461
# 40    48.605153
# 41    50.211594
# 42    48.747462
# 43    49.615496
# 44    50.264027
# 45    49.303966
# 46    49.127104
# 47    49.852564
# 48    49.852564
# 49    49.655941
# 50    51.022351
# Name: Male_Average, dtype: float64

# %%
col2 = states.loc[:,['2014_Female','2013_Female','2012_Female','2011_Female','2010_Female']]
states['Female_Average'] = col2.mean(axis=1)
states['Female_Average']
# Out:
# 0     51.521300
# 1     47.631451
# 2     50.287045
# 3     50.893315
# 4     50.335023
# 5     49.806741
# 6     51.233241
# 7     51.576639
# 8     52.500238
# 9     51.109354
# 10    51.246250
# 11    49.772803
# 12    49.899196
# 13    50.908772
# 14    50.734668
# 15    50.339729
# 16    50.205290
# 17    50.753478
# 18    51.061705
# 19    51.024943
# 20    51.548655
# 21    51.517012
# 22    50.856069
# 23    50.287631
# 24    51.436536
# 25    50.939169
# 26    49.716598
# 27    50.199849
# 28    49.724303
# 29    50.550846
# 30    51.225270
# 31    50.492918
# 32    51.503375
# 33    51.310622
# 34    48.744886
# 35    51.057187
# 36    50.454167
# 37    50.494196
# 38    51.095862
# 39    51.517280
# 40    51.425066
# 41    49.674438
# 42    51.232483
# 43    50.361039
# 44    49.706279
# 45    50.659219
# 46    50.830802
# 47    50.082426
# 48    50.082426
# 49    50.313183
# 50    48.955144
# Name: Female_Average, dtype: float64

# %%
states.set_index('Code')
# Out:
#                   Location  2014_Health_Spending  2013_Health_Spending  \
# Code
# AL                 Alabama                7281.0                6996.0
# AK                  Alaska               11064.0               10428.0
# AZ                 Arizona                6452.0                6262.0
# AR                Arkansas                7408.0                6929.0
# CA              California                7549.0                7256.0
# CO                Colorado                6804.0                6472.0
# CT             Connecticut                9859.0                9517.0
# DE                Delaware               10254.0                9766.0
# DC    District of Columbia               11944.0               11466.0
# FL                 Florida                8076.0                7688.0
# GA                 Georgia                6587.0                6249.0
# HI                  Hawaii                7299.0                6955.0
# ...

# %%
lst= []
for x in states['Location']:
    lst.append(x)
lst
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
df= pd.DataFrame({'s_name':lst})
df.set_index('s_name')
# Out:
# Empty DataFrame
# Columns: []
# Index: [Alabama, Alaska, Arizona, Arkansas, California, Colorado, Connecticut, Delaware, District of Columbia, Florida, Georgia, Hawaii, Idaho, Illinois, Indiana, Iowa, Kansas, Kentucky, Louisiana, Maine, Maryland, Massachusetts, Michigan, Minnesota, Mississippi, Missouri, Montana, Nebraska, Nevada, New Hampshire, New Jersey, New Mexico, New York, North Carolina, North Dakota, Ohio, Oklahoma, Oregon, Pennsylvania, Rhode Island, South Carolina, South Dakota, Tennessee, Texas, Utah, Vermont, Virginia, Washington, West Virginia, Wisconsin, Wyoming]

# %%
type(["Location"])
# Out:
# list

# %%
ax = plt.gca()
x=np.arange(1,52,1)
states.plot(kind='line',x= 'Location',y='Male_Average',ax=ax)
states.plot(kind='line',x= 'Location',y='Female_Average',ax=ax)
ax.set_xticks(x)
ax.set_xticklabels(states['Location'],rotation='vertical',fontsize=7)
plt.ylabel('Ration Men:Women by State')
plt.show()

# %%
states['2014_Middle_Adult']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2014_Middle_Adult'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-4f97f7e88d34> in <module>()
# ...

# %%
states['2014_Middle_Adult '] = states['2014_Middle_Adult '].astype(float)
states['2013_Middle_Adult '] = states['2013_Middle_Adult '].astype(float)
states['2012_Middle_Adult '] = states['2012_Middle_Adult '].astype(float)
states['2011_Middle_Adult '] = states['2011_Middle_Adult '].astype(float)
states['2010_Middle_Adult '] = states['2010_Middle_Adult '].astype(float)
states['2014_Senior'] = states['2014_Senior'].astype(float)
states['2013_Senior'] = states['2013_Senior'].astype(float)
states['2012_Senior'] = states['2012_Senior'].astype(float)
states['2011_Senior'] = states['2011_Senior'].astype(float)
states['2010_Senior'] = states['2010_Senior'].astype(float)
states['2014_Young_Adult'] = states['2014_Young_Adult'].astype(float)
states['2013_Young_Adult'] = states['2013_Young_Adult'].astype(float)
states['2012_Young_Adult'] = states['2012_Young_Adult'].astype(float)
states['2011_Young_Adult'] = states['2011_Young_Adult'].astype(float)
states['2010_Young_Adult'] = states['2010_Young_Adult'].astype(float)
states['2014_Childhood'] = states['2014_Childhood'].astype(float)
states['2013_Childhood'] = states['2013_Childhood'].astype(float)
states['2012_Childhood'] = states['2012_Childhood'].astype(float)
states['2011_Childhood'] = states['2011_Childhood'].astype(float)
states['2010_Childhood'] = states['2010_Childhood'].astype(float)

# %%
col = states.loc[:,['2014_Childhood','2013_Childhood','2012_Childhood','2011_Childhood','2010_Childhood']]
states['Childhood_Average'] = col.mean(axis=1)
states['Childhood_Average']
# Out:
# 0     25.904676
# 1     28.380923
# 2     27.409337
# 3     26.751548
# 4     27.037984
# 5     26.456721
# 6     24.833387
# 7     25.041310
# 8     27.699952
# 9     24.920852
# 10    25.529271
# 11    25.372265
# 12    25.209882
# 13    25.402656
# 14    25.172822
# 15    25.043313
# 16    25.264660
# 17    25.213443
# 18    25.424868
# 19    24.501540
# 20    25.262261
# 21    25.268600
# 22    24.862849
# 23    25.231000
# 24    25.226376
# 25    25.141350
# 26    24.931905
# 27    25.296363
# 28    25.501168
# 29    24.649484
# 30    25.047082
# 31    25.125160
# 32    25.436780
# 33    25.339294
# 34    25.555083
# 35    24.948145
# 36    25.342753
# 37    25.296590
# 38    24.905939
# 39    25.122481
# 40    25.203045
# 41    25.113695
# 42    25.210551
# 43    25.666304
# 44    26.089228
# 45    24.735208
# 46    25.460166
# 47    25.413679
# 48    24.866382
# 49    25.061038
# 50    25.343321
# Name: Childhood_Average, dtype: float64

# %%
col = states.loc[:,['2014_Middle_Adult ','2013_Middle_Adult ','2012_Middle_Adult  ','2011_Middle_Adult ','2010_Middle_Adult ']]
states['Middle_Adult_Average'] = col.mean(axis=1)
states['Middle_Adult_Average']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# 0     33.321629
# 1     33.388208
# 2     30.859293
# 3     32.070848
# 4     32.032912
# 5     33.257523
# 6     25.143537
# 7     25.533971
# 8     25.740009
# 9     26.457153
# 10    24.216192
# 11    25.920103
# 12    24.532992
# 13    24.826186
# 14    24.813422
# 15    25.358022
# 16    24.889153
# 17    25.148288
# 18    24.869924
# 19    26.009912
# 20    24.912779
# 21    25.278919
# 22    25.086903
# 23    24.970650
# 24    24.785738
# 25    25.284701
# 26    25.686085
# 27    24.998636
# 28    24.937879
# 29    25.166125
# 30    25.162749
# 31    25.006801
# 32    25.359666
# 33    25.012530
# 34    25.582166
# ...

# %%
col = states.loc[:,['2014_Young_Adult','2013_Young_Adult ','2012_Young_Adult  ','2011_Young_Adult ','2010_Young_Adult ']]
states['Young_Adult_Average'] = col.mean(axis=1)
states['Young_Adult_Average']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# 0     26.245068
# 1     30.311947
# 2     26.881570
# 3     26.209188
# 4     28.949331
# 5     28.697262
# 6     24.299435
# 7     25.631825
# 8     39.009329
# 9     25.161521
# 10    27.692217
# 11    27.444478
# 12    26.285075
# 13    27.219510
# 14    26.158899
# 15    25.576326
# 16    26.632958
# 17    26.226272
# 18    27.825196
# 19    22.703168
# 20    26.592143
# 21    26.670112
# 22    24.865611
# 23    26.297419
# 24    26.601570
# 25    26.121621
# 26    25.173041
# 27    26.594431
# 28    27.752152
# 29    23.401743
# 30    25.394639
# 31    26.279066
# 32    27.676116
# 33    26.568647
# 34    28.819613
# ...

# %%
col = states.loc[:,['2014_Senior','2013_Senior','2012_Senior','2011_Senior','2010_Senior']]
states['Senior_Average'] = col.mean(axis=1)
states['Senior_Average']
# Out:
# 0     14.547121
# 1      8.634091
# 2     14.867635
# 3     15.023223
# 4     12.148153
# 5     11.827086
# 6     24.886311
# 7     24.898669
# 8     24.131102
# 9     24.547673
# 10    25.490165
# 11    24.785351
# 12    25.825719
# 13    25.174066
# 14    25.356288
# 15    25.273318
# 16    25.537488
# 17    25.110113
# 18    25.294152
# 19    24.404189
# 20    25.046161
# 21    24.730997
# 22    25.045226
# 23    25.229572
# 24    25.455471
# 25    25.122289
# 26    24.915744
# 27    25.536993
# 28    25.132092
# 29    24.595931
# 30    24.997948
# 31    25.355982
# 32    24.810651
# 33    25.134940
# 34    25.167479
# 35    25.089912
# 36    25.447607
# 37    24.826564
# 38    24.786065
# 39    24.695795
# 40    25.026996
# 41    25.500468
# 42    25.069735
# 43    25.849372
# 44    26.728783
# 45    24.567332
# 46    25.024138
# 47    25.023841
# 48    24.610397
# 49    25.075517
# 50    25.243480
# Name: Senior_Average, dtype: float64

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(20,5))

plt.title('Average Age Distribution by State ', fontsize = 20)
plt.xlabel('States', fontsize = 20)
plt.ylabel('Ages', fontsize = 20)

x_axis = np.arange(0, len(states['Senior_Average']))
plt.ylim = (0,100)

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, states['Location'], rotation=90)

senior= plt.scatter(states['Location'], states['Senior_Average'], marker = "o", edgecolors="black", facecolors='g', s=80)
middle_adult = plt.scatter(states['Location'], states['Middle_Adult_Average'], marker = "o", edgecolors="black",facecolors='b', s=80)
childhood= plt.scatter(states['Location'], states['Childhood_Average'], marker = "o", edgecolors="black", facecolors='orange', s=80)
young_adult= plt.scatter(states['Location'], states['Young_Adult_Average'], marker = "o", edgecolors="black", facecolors='purple', s=80)

chart_legend = plt.legend(handles=(senior,middle_adult,childhood,young_adult))
# plt.grid()
plt.savefig("HealthSpendingbyStats.png", bbox_inches='tight')
