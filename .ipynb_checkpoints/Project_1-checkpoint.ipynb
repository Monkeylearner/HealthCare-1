# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# %%
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Healthcare data
data = pd.ExcelFile('/Users/honghongzhang/Desktop/HealthCare/US_Healthcare_Expense_per_state_2010_2014.xls')
Healthcare = pd.read_excel(data,'clean_data')
Healthcare.head()
# Out:
#      Location  2014_Health_Spending  2013_Health_Spending  \
# 0     Alabama                  7281                  6996
# 1      Alaska                 11064                 10428
# 2     Arizona                  6452                  6262
# 3    Arkansas                  7408                  6929
# 4  California                  7549                  7256
#
#    2012_Health_Spending  2011_Health_Spending  2010_Health_Spending  \
# 0                  6821                  6541                  6421
# 1                 10130                  9586                  9129
# 2                  6183                  6076                  6027
# 3                  6804                  6585                  6412
# 4                  7018                  6737                  6480
#
#    2014_Smoking  2013_Smoking  2012_Smoking  2011_Smoking     ...       \
# 0      0.277492      0.275937      0.279381      0.287698     ...
# ...

# %%
Health_spending = Healthcare.iloc[0:51, 0:6]
Health_spending.head()
# Out:
#      Location  2014_Health_Spending  2013_Health_Spending  \
# 0     Alabama                  7281                  6996
# 1      Alaska                 11064                 10428
# 2     Arizona                  6452                  6262
# 3    Arkansas                  7408                  6929
# 4  California                  7549                  7256
#
#    2012_Health_Spending  2011_Health_Spending  2010_Health_Spending
# 0                  6821                  6541                  6421
# 1                 10130                  9586                  9129
# 2                  6183                  6076                  6027
# 3                  6804                  6585                  6412
# 4                  7018                  6737                  6480

# %%
#Health_spending_new = Health_spending

#Health_spending_new["2014_Health_Spending"] =Health_spending["2014_Health_Spending"].str.replace('$', '')
#Health_spending_new["2013_Health_Spending"] =Health_spending["2013_Health_Spending"].str.replace('$', '')
#Health_spending_new["2012_Health_Spending"] =Health_spending["2012_Health_Spending"].str.replace('$', '')
#Health_spending_new["2011_Health_Spending"] =Health_spending["2011_Health_Spending"].str.replace('$', '')
#Health_spending_new["2010_Health_Spending"] =Health_spending["2010_Health_Spending"].str.replace('$', '')

#Health_spending_new.set_index("Location")
#Health_spending_new = Health_spending_new.astype('float64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-76826f2bae7a> in <module>()
#       1 Health_spending_new = Health_spending
#       2
# ----> 3 Health_spending_new["2014_Health_Spending"] =Health_spending["2014_Health_Spending"].str.replace('$', '')
#       4 Health_spending_new["2013_Health_Spending"] =Health_spending["2013_Health_Spending"].str.replace('$', '')
#       5 Health_spending_new["2012_Health_Spending"] =Health_spending["2012_Health_Spending"].str.replace('$', '')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
# ...

# %%
# Generate the Plot 
plt.figure(figsize=(20,10))
plt.title('Health Spending by state', fontsize = 12)
plt.xlabel('States', fontsize = 10)
plt.ylabel('Health_Spending', fontsize = 10)


x_axis = np.arange(0, len(Health_spending_new))

[plt.scatter(x_axis, Health_spending_new[group], marker = "o", edgecolors="black", s=80) for group in Health_spending_new]
plt.ylim(Health_spending_new.min()+1, Health_spending_new.max()+1)

plt.legend(bbox_to_anchor=(1, 1), frameon=False, title="Media Sources")
plt.savefig("Sentiment Analysis of Media Tweets", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(20,10))

plt.title('Health Spending by state ', fontsize = 12)
plt.xlabel('States', fontsize = 10)
plt.ylabel('Health_Spending', fontsize = 10)

x_axis = np.arange(0, len(Health_spending_new))
plt.ylim = (0, 12000, 2000)

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, Health_spending_new.index, rotation=45)

[plt.scatter(x_axis, Health_spending_new[group], marker = "o", edgecolors="black", s=80) for group in Health_spending_new]

plt.legend(bbox_to_anchor=(1, 1), frameon=False, title="Years")
#plt.savefig(HealthSpendingbyStats.png", bbox_inches='tight')
