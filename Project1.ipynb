# %% [markdown]
# ## Project1

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Raw data file
file_to_load = "/Users/VINESH/Desktop/HealthCare/HealthCare/U.S._Chronic_Disease_Indicators.csv"

# Read purchasing file and store into pandas data frame
disease_df = pd.read_csv(file_to_load, low_memory=False)
# print(disease_df)
disease_yr = disease_df["YearEnd"].unique()
disease_yr
# Out:
# array([2016, 2015, 2013, 2014, 2012, 2011, 2010, 2008, 2007, 2001],
#       dtype=int64)

# %%
year_gb = disease_df.groupby(["Topic","LocationAbbr"]).first()
year_gb.head()
# print (year_gb)
# Out:
#                       YearStart  YearEnd LocationDesc DataSource  \
# Topic   LocationAbbr
# Alcohol AK                 2016     2016       Alaska      BRFSS
#         AL                 2016     2016      Alabama      BRFSS
#         AR                 2016     2016     Arkansas      BRFSS
#         AZ                 2016     2016      Arizona      BRFSS
#         CA                 2016     2016   California      BRFSS
#
#                                                                Question  \
# Topic   LocationAbbr
# Alcohol AK            Binge drinking prevalence among adults aged >=...
#         AL            Binge drinking prevalence among adults aged >=...
#         AR            Binge drinking prevalence among adults aged >=...
#         AZ            Binge drinking prevalence among adults aged >=...
#         CA            Binge drinking prevalence among adults aged >=...
#
#                      Response DataValueUnit     DataValueType DataValue  \
# ...

# %%
ins_gby_sex = insurance_df.groupby(["age", "sex", "bmi", "children","smoker","region","charges"]).count()
ins_gby_sex.head()
# g1 = df1.groupby( [ "Name", "City"] ).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(18, female, 20.79, 0, no, southeast, 1607.5101), (18, female, 21.66, 0, yes, northeast, 14283.4594), (18, female, 24.09, 1, no, southeast, 2201.0971), (18, female, 25.08, 0, no, northeast, 2196.4732), (18, female, 26.315, 0, no, northeast, 2198.18985)]
