# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
from scipy import stats
from statsmodels.formula.api import ols

# %%
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Healthcare data
data = pd.ExcelFile('/Users/honghongzhang/Desktop/HealthCare/US_Healthcare_Expense_per_state_2010_2014.xls')
Healthcare = pd.read_excel(data,'clean_data')
Healthcare.head()
# Out:
#      Location  2014_Health_Spending  2013_Health_Spending  \
# 0     Alabama                  7281                  6996
# 1      Alaska                 11064                 10428
# 2     Arizona                  6452                  6262
# 3    Arkansas                  7408                  6929
# 4  California                  7549                  7256
#
#    2012_Health_Spending  2011_Health_Spending  2010_Health_Spending  \
# 0                  6821                  6541                  6421
# 1                 10130                  9586                  9129
# 2                  6183                  6076                  6027
# 3                  6804                  6585                  6412
# 4                  7018                  6737                  6480
#
#    2014_Smoking  2013_Smoking  2012_Smoking  2011_Smoking     ...       \
# 0      0.277492      0.275937      0.279381      0.287698     ...
# ...

# %%
Health_Spending_mean = Healthcare[["2014_Health_Spending", "2013_Health_Spending", "2012_Health_Spending", "2011_Health_Spending", \
                                  "2010_Health_Spending"]].mean(axis=1)
Healthcare["Health_Spending_mean"]=Health_Spending_mean
Healthcare.head()
Smoking_mean = Healthcare[["2014_Smoking","2013_Smoking","2012_Smoking","2011_Smoking","2010_Smoking"]].mean(axis=1)
Healthcare["Smoking_mean"]=Smoking_mean
Income_mean = Healthcare[["2014_Income","2013_Income","2012_Income","2011_Income","2010_Income"]].mean(axis=1)
Healthcare["Income_mean"]=Income_mean
GDP_mean = Healthcare[["2014_GDP","2013_GDP","2012_GDP","2011_GDP","2010_GDP"]].mean(axis=1)
Healthcare["GDP_mean"]=GDP_mean
Male_mean = Healthcare[["2014_Male","2013_Male","2012_Male","2011_Male","2010_Male"]].mean(axis=1)
Healthcare["Male_mean"] = Male_mean
Female_mean = Healthcare[["2014_Female","2013_Female","2012_Female","2011_Female","2010_Female"]].mean(axis=1)
Healthcare["Female_mean"] = Female_mean
Childhood_mean = Healthcare[["2014_Childhood","2013_Childhood","2012_Childhood","2011_Childhood","2010_Childhood"]].mean(axis=1)
Healthcare["Childhood_mean"] = Childhood_mean
Young_Adult_mean = Healthcare[["2014_Young_Adult","2013_Young_Adult","2012_Young_Adult","2011_Young_Adult","2014_Young_Adult","2014_Young_Adult"]].mean(axis=1)
Healthcare["Young_Adult_mean"] = Young_Adult_mean
Middle_Adult_mean = Healthcare[["2014_Middle_Adult", "2013_Middle_Adult", "2012_Middle_Adult", "2011_Middle_Adult", "2010_Middle_Adult"]].mean(axis=1)
Healthcare["Middle_Adult_mean"] = Middle_Adult_mean
Senior_mean = Healthcare[["2014_Senior","2013_Senior","2012_Senior","2011_Senior","2010_Senior"]].mean(axis=1)
Healthcare["Senior_mean"] = Senior_mean
Healthcare.head()
# Out:
#      Location  2014_Health_Spending  2013_Health_Spending  \
# 0     Alabama                  7281                  6996
# 1      Alaska                 11064                 10428
# 2     Arizona                  6452                  6262
# 3    Arkansas                  7408                  6929
# 4  California                  7549                  7256
#
#    2012_Health_Spending  2011_Health_Spending  2010_Health_Spending  \
# 0                  6821                  6541                  6421
# 1                 10130                  9586                  9129
# 2                  6183                  6076                  6027
# 3                  6804                  6585                  6412
# 4                  7018                  6737                  6480
#
#    2014_Smoking  2013_Smoking  2012_Smoking  2011_Smoking     ...       \
# 0      0.277492      0.275937      0.279381      0.287698     ...
# ...

# %%
#y = Health_Spending_mean
#model_smoking = ols("y ~ Smoking_mean", Healthcare).fit()
#print(model_smoking.summary())
#model_Income = ols("y ~ Income_mean", Healthcare).fit()
#print(model_Income.summary())
#model_GDP = ols("y ~ GDP_mean", Healthcare).fit()
#print(model_GDP.summary())
#model_Male = ols("y ~ Male_mean", Healthcare).fit()
#print(model_Male.summary())
#model_Female = ols("y ~ Female_mean", Healthcare).fit()
#print(model_Female.summary())
#model_Childhood = ols("y ~ Childhood_mean", Healthcare).fit()
#print(model_Childhood.summary())
#model_Young_Adult = ols("y ~ Young_Adult_mean", Healthcare).fit()
#print(model_Young_Adult.summary())
#model_Middle_Adult = ols("y ~ Middle_Adult_mean", Healthcare).fit()
#print(model_Middle_Adult.summary())
#model_Senior = ols("y ~ Senior_mean", Healthcare).fit()
#print(model_Senior.summary())

# %%
x_axis = [Smoking_mean, Income_mean, GDP_mean, Male_mean, Female_mean, Childhood_mean,\
         Young_Adult_mean, Middle_Adult_mean, Senior_mean]
y = Health_Spending_mean
i=1
for x in x_axis:
    model_i = ols("y ~ x", Healthcare).fit()
    print(model_i.summary())
    i +=1
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                  0.001589
# Date:                Tue, 11 Sep 2018   Prob (F-statistic):              0.968
# Time:                        20:59:52   Log-Likelihood:                -432.57
# No. Observations:                  51   AIC:                             869.1
# Df Residuals:                      49   BIC:                             873.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7670.7367   2926.803      2.621      0.012    1789.105    1.36e+04
# ...

# %%
from statsmodels.formula.api import ols
y = Health_Spending_mean
model_1 = ols("y ~ Health_Spending_mean", Healthcare).fit()
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.654e+31
# Date:                Tue, 11 Sep 2018   Prob (F-statistic):               0.00
# Time:                        20:13:39   Log-Likelihood:                 1301.2
# No. Observations:                  51   AIC:                            -2598.
# Df Residuals:                      49   BIC:                            -2595.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             4.547e-13   1.94e-12      0.235      0.815   -3.44e-12    4.35e-12
# ...

# %%
y = Healthcare_mean
smoking_percent = Healthcare.iloc[:,6]
income= Healthcare.iloc[:,11]
gdp=Healthcare.iloc[:,16]

model1 = ols("y ~ smoking_percent+income+gdp", Healthcare).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.560
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     19.98
# Date:                Tue, 11 Sep 2018   Prob (F-statistic):           1.72e-08
# Time:                        19:25:18   Log-Likelihood:                -414.85
# No. Observations:                  51   AIC:                             837.7
# Df Residuals:                      47   BIC:                             845.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -4613.1759   2807.466     -1.643      0.107   -1.03e+04    1034.718
# ...

# %%
Health_spending = Healthcare.iloc[0:51, 0:6]
Health_spending_new = Health_spending.set_index("Location")
Health_spending_new.head()
# Out:
#             2014_Health_Spending  2013_Health_Spending  2012_Health_Spending  \
# Location
# Alabama                     7281                  6996                  6821
# Alaska                     11064                 10428                 10130
# Arizona                     6452                  6262                  6183
# Arkansas                    7408                  6929                  6804
# California                  7549                  7256                  7018
#
#             2011_Health_Spending  2010_Health_Spending
# Location
# Alabama                     6541                  6421
# Alaska                      9586                  9129
# Arizona                     6076                  6027
# Arkansas                    6585                  6412
# California                  6737                  6480

# %%
# plot age data by state
plt.figure(figsize=(8,3))
ax = plt.gca()
x=np.arange(1,52,1)
Healthcare.plot(kind='line',x='Location',y='Childhood_Average',ax=ax)
Healthcare.plot(kind='line',x='Location',y='Young_Adult_Average',ax=ax)
Healthcare.plot(kind='line',x='Location',y='Middle_Adult_Average',ax=ax)
Healthcare.plot(kind='line',x='Location',y='Senior_Average',ax=ax)
ax.set_xticks(x)
ax.set_xticklabels(Healthcare['Location'],rotation='vertical',fontsize=7)
plt.ylabel('Age groups by State')
plt.show()
plt.savefig("Age groups by state-1.png", bbox_inches='tight')
